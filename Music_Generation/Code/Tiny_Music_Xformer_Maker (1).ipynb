# %% [markdown]
# # Bachelor Graduation Project Part 2: Music Generation with X-Transformers
#
#
# Powered by tegridy-tools: https://github.com/asigalov61/tegridy-tools

# %% [markdown]
# # (SETUP ENVIRONMENT)

# %%
# @title NVIDIA GPU Check
# !nvidia-smi
# Out:
# Tue May 14 09:24:20 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off | 00000000:00:04.0 Off |                    0 |
# | N/A   31C    P0              40W / 400W |      2MiB / 40960MiB |      0%      Default |
# |                                         |                      |             Disabled |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
#@title Install all dependencies (run only once per session)
# !git clone https://github.com/asigalov61/tegridy-tools
# !pip install einops
# !pip install torch-summary
# Out:
# Cloning into 'tegridy-tools'...
# remote: Enumerating objects: 3644, done.
# remote: Counting objects: 100% (402/402), done.
# remote: Compressing objects: 100% (165/165), done.
# remote: Total 3644 (delta 330), reused 275 (delta 235), pack-reused 3242
# Receiving objects: 100% (3644/3644), 149.84 MiB | 12.05 MiB/s, done.
# Resolving deltas: 100% (2387/2387), done.
# Collecting einops
#   Downloading einops-0.8.0-py3-none-any.whl (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 1.7 MB/s eta 0:00:00
# Installing collected packages: einops
# Successfully installed einops-0.8.0
# Collecting torch-summary
#   Downloading torch_summary-1.4.5-py3-none-any.whl (16 kB)
# Installing collected packages: torch-summary
# Successfully installed torch-summary-1.4.5

# %%
#@title Import all needed modules

print('Loading modules...')

import os
import pickle
import secrets
import statistics
import tqdm
import math
import copy
import torch
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset

import matplotlib.pyplot as plt

from torchsummary import summary
from sklearn import metrics

# %cd /content/tegridy-tools/tegridy-tools/

import TMIDIX

# %cd /content/tegridy-tools/tegridy-tools/X-Transformer

from x_transformer_1_23_2 import *

torch.set_float32_matmul_precision('high')
torch.backends.cuda.matmul.allow_tf32 = True # allow tf32 on matmul
torch.backends.cudnn.allow_tf32 = True # allow tf32 on cudnn

# %cd /content/

if not os.path.exists('/content/Dataset'):
    os.makedirs('/content/Dataset')

if not os.path.exists('/content/INTS'):
    os.makedirs('/content/INTS')

import random

from joblib import Parallel, delayed, parallel_config

print('PyTorch version:', torch.__version__)
print('Done')
# Out:
# Loading modules...
# /content/tegridy-tools/tegridy-tools
# /content/tegridy-tools/tegridy-tools/X-Transformer
# /content
# PyTorch version: 2.2.1+cu121
# Done

# %% [markdown]
# # (DOWNLOAD AND UNZIP MIDI DATASET)

# %%
# @title Download and unzip Maestro v2 MIDI Dataset
# %cd /content/Dataset
# !wget https://github.com/asigalov61/Tegridy-MIDI-Dataset/raw/master/Misc/POP909-Piano-Violin-CC-BY-NC-SA.zip
# !unzip POP909-Piano-Violin-CC-BY-NC-SA.zip
# !rm POP909-Piano-Violin-CC-BY-NC-SA.zip
# %cd /content/
# Out:
# /content/Dataset
# --2024-05-14 09:24:54--  https://github.com/asigalov61/Tegridy-MIDI-Dataset/raw/master/Misc/POP909-Piano-Violin-CC-BY-NC-SA.zip
# Resolving github.com (github.com)... 20.205.243.166
# Connecting to github.com (github.com)|20.205.243.166|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/asigalov61/Tegridy-MIDI-Dataset/master/Misc/POP909-Piano-Violin-CC-BY-NC-SA.zip [following]
# --2024-05-14 09:24:55--  https://raw.githubusercontent.com/asigalov61/Tegridy-MIDI-Dataset/master/Misc/POP909-Piano-Violin-CC-BY-NC-SA.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 16922099 (16M) [application/zip]
# Saving to: ‘POP909-Piano-Violin-CC-BY-NC-SA.zip’
#
# POP909-Piano-Violin 100%[===================>]  16.14M  --.-KB/s    in 0.05s
#
# 2024-05-14 09:24:57 (337 MB/s) - ‘POP909-Piano-Violin-CC-BY-NC-SA.zip’ saved [16922099/16922099]
#
# Archive:  POP909-Piano-Violin-CC-BY-NC-SA.zip
#   inflating: POP909-001.mid
#   inflating: POP909-001-v1.mid
#   inflating: POP909-001-v2.mid
#   inflating: POP909-001-v3.mid
#   inflating: POP909-003.mid
#   inflating: POP909-003-v1.mid
#   inflating: POP909-003-v2.mid
#   inflating: POP909-004.mid
#   inflating: POP909-004-v1.mid
#   inflating: POP909-004-v2.mid
#   inflating: POP909-006.mid
#   inflating: POP909-006-v1.mid
#   inflating: POP909-007.mid
#   inflating: POP909-007-v1.mid
#   inflating: POP909-008.mid
#   inflating: POP909-008-v1.mid
#   inflating: POP909-008-v3.mid
#   inflating: POP909-009.mid
#   inflating: POP909-009-v1.mid
#   inflating: POP909-011.mid
#   inflating: POP909-011-v1.mid
#   inflating: POP909-011-v2.mid
#   inflating: POP909-011-v3.mid
#   inflating: POP909-013.mid
#   inflating: POP909-014.mid
#   inflating: POP909-014-v1.mid
#   inflating: POP909-014-v2.mid
#   inflating: POP909-014-v3.mid
#   inflating: POP909-015.mid
#   inflating: POP909-015-v1.mid
#   inflating: POP909-015-v2.mid
#   inflating: POP909-015-v3.mid
#   inflating: POP909-015-v4.mid
#   inflating: POP909-016.mid
#   inflating: POP909-016-v1.mid
#   inflating: POP909-016-v2.mid
#   inflating: POP909-016-v3.mid
#   inflating: POP909-018-v1.mid
#   inflating: POP909-018-v2.mid
#   inflating: POP909-019.mid
#   inflating: POP909-019-v1.mid
#   inflating: POP909-019-v2.mid
#   inflating: POP909-019-v3.mid
#   inflating: POP909-021.mid
#   inflating: POP909-021-v1.mid
#   inflating: POP909-021-v2.mid
#   inflating: POP909-023.mid
#   inflating: POP909-023-v1.mid
#   inflating: POP909-023-v2.mid
#   inflating: POP909-024.mid
#   inflating: POP909-024-v1.mid
#   inflating: POP909-024-v2.mid
#   inflating: POP909-025-v1.mid
#   inflating: POP909-025-v2.mid
#   inflating: POP909-026.mid
#   inflating: POP909-026-v1.mid
#   inflating: POP909-026-v2.mid
#   inflating: POP909-027.mid
#   inflating: POP909-027-v1.mid
#   inflating: POP909-027-v2.mid
#   inflating: POP909-028.mid
#   inflating: POP909-028-v1.mid
#   inflating: POP909-029.mid
#   inflating: POP909-029-v1.mid
#   inflating: POP909-029-v2.mid
#   inflating: POP909-029-v3.mid
#   inflating: POP909-030.mid
#   inflating: POP909-030-v1.mid
#   inflating: POP909-030-v2.mid
#   inflating: POP909-031.mid
#   inflating: POP909-031-v1.mid
#   inflating: POP909-032.mid
#   inflating: POP909-032-v1.mid
#   inflating: POP909-032-v2.mid
#   inflating: POP909-032-v3.mid
#   inflating: POP909-032-v4.mid
#   inflating: POP909-033.mid
#   inflating: POP909-033-v1.mid
#   inflating: POP909-033-v2.mid
#   inflating: POP909-034.mid
#   inflating: POP909-034-v1.mid
#   inflating: POP909-035.mid
#   inflating: POP909-035-v1.mid
#   inflating: POP909-035-v2.mid
#   inflating: POP909-035-v3.mid
#   inflating: POP909-036.mid
#   inflating: POP909-036-v1.mid
#   inflating: POP909-037.mid
#   inflating: POP909-037-v1.mid
#   inflating: POP909-037-v2.mid
#   inflating: POP909-037-v3.mid
#   inflating: POP909-038.mid
#   inflating: POP909-038-v1.mid
#   inflating: POP909-040.mid
#   inflating: POP909-040-v1.mid
#   inflating: POP909-040-v2.mid
#   inflating: POP909-041.mid
#   inflating: POP909-041-v1.mid
#   inflating: POP909-041-v2.mid
#   inflating: POP909-041-v3.mid
#   inflating: POP909-041-v4.mid
#   inflating: POP909-042.mid
#   inflating: POP909-042-v1.mid
#   inflating: POP909-042-v2.mid
#   inflating: POP909-042-v3.mid
#   inflating: POP909-042-v4.mid
#   inflating: POP909-043.mid
#   inflating: POP909-043-v3.mid
#   inflating: POP909-044.mid
#   inflating: POP909-044-v1.mid
#   inflating: POP909-044-v2.mid
#   inflating: POP909-045.mid
#   inflating: POP909-045-v1.mid
#   inflating: POP909-045-v2.mid
#   inflating: POP909-046.mid
#   inflating: POP909-046-v1.mid
#   inflating: POP909-046-v2.mid
#   inflating: POP909-047.mid
#   inflating: POP909-047-v1.mid
#   inflating: POP909-047-v2.mid
#   inflating: POP909-047-v3.mid
#   inflating: POP909-047-v4.mid
#   inflating: POP909-048.mid
#   inflating: POP909-048-v1.mid
#   inflating: POP909-048-v2.mid
#   inflating: POP909-049.mid
#   inflating: POP909-049-v1.mid
#   inflating: POP909-049-v2.mid
#   inflating: POP909-049-v3.mid
#   inflating: POP909-049-v4.mid
#   inflating: POP909-050.mid
#   inflating: POP909-050-v1.mid
#   inflating: POP909-050-v2.mid
#   inflating: POP909-051.mid
#   inflating: POP909-051-v1.mid
#   inflating: POP909-052.mid
#   inflating: POP909-052-v1.mid
#   inflating: POP909-052-v2.mid
#   inflating: POP909-053.mid
#   inflating: POP909-053-v2.mid
#   inflating: POP909-054.mid
#   inflating: POP909-054-v1.mid
#   inflating: POP909-054-v2.mid
#   inflating: POP909-054-v3.mid
#   inflating: POP909-055.mid
#   inflating: POP909-055-v1.mid
#   inflating: POP909-055-v2.mid
#   inflating: POP909-055-v3.mid
#   inflating: POP909-055-v4.mid
#   inflating: POP909-056.mid
#   inflating: POP909-056-v1.mid
#   inflating: POP909-056-v2.mid
#   inflating: POP909-056-v3.mid
#   inflating: POP909-057.mid
#   inflating: POP909-057-v1.mid
#   inflating: POP909-057-v2.mid
#   inflating: POP909-060.mid
#   inflating: POP909-060-v1.mid
#   inflating: POP909-060-v2.mid
#   inflating: POP909-061.mid
#   inflating: POP909-061-v1.mid
#   inflating: POP909-061-v2.mid
#   inflating: POP909-062.mid
#   inflating: POP909-062-v1.mid
#   inflating: POP909-062-v2.mid
#   inflating: POP909-063.mid
#   inflating: POP909-063-v1.mid
#   inflating: POP909-063-v2.mid
#   inflating: POP909-063-v3.mid
#   inflating: POP909-063-v4.mid
#   inflating: POP909-064.mid
#   inflating: POP909-064-v1.mid
#   inflating: POP909-064-v2.mid
#   inflating: POP909-064-v3.mid
#   inflating: POP909-065.mid
#   inflating: POP909-065-v1.mid
#   inflating: POP909-066.mid
#   inflating: POP909-066-v1.mid
#   inflating: POP909-066-v2.mid
#   inflating: POP909-066-v3.mid
#   inflating: POP909-066-v4.mid
#   inflating: POP909-067.mid
#   inflating: POP909-067-v1.mid
#   inflating: POP909-067-v2.mid
#   inflating: POP909-069.mid
#   inflating: POP909-069-v1.mid
#   inflating: POP909-069-v2.mid
#   inflating: POP909-069-v3.mid
#   inflating: POP909-069-v4.mid
#   inflating: POP909-069-v5.mid
#   inflating: POP909-069-v6.mid
#   inflating: POP909-070.mid
#   inflating: POP909-070-v1.mid
#   inflating: POP909-070-v2.mid
#   inflating: POP909-073.mid
#   inflating: POP909-073-v1.mid
#   inflating: POP909-073-v2.mid
#   inflating: POP909-073-v3.mid
#   inflating: POP909-073-v4.mid
#   inflating: POP909-073-v5.mid
#   inflating: POP909-073-v6.mid
#   inflating: POP909-074.mid
#   inflating: POP909-074-v1.mid
#   inflating: POP909-074-v2.mid
#   inflating: POP909-075.mid
#   inflating: POP909-075-v1.mid
#   inflating: POP909-075-v2.mid
#   inflating: POP909-076.mid
#   inflating: POP909-076-v1.mid
#   inflating: POP909-076-v2.mid
#   inflating: POP909-076-v3.mid
#   inflating: POP909-082.mid
#   inflating: POP909-082-v1.mid
#   inflating: POP909-082-v2.mid
#   inflating: POP909-082-v3.mid
#   inflating: POP909-082-v4.mid
#   inflating: POP909-083.mid
#   inflating: POP909-083-v1.mid
#   inflating: POP909-083-v2.mid
#   inflating: POP909-083-v3.mid
#   inflating: POP909-084.mid
#   inflating: POP909-085-v1.mid
#   inflating: POP909-086.mid
#   inflating: POP909-086-v1.mid
#   inflating: POP909-086-v2.mid
#   inflating: POP909-087.mid
#   inflating: POP909-087-v1.mid
#   inflating: POP909-087-v2.mid
#   inflating: POP909-087-v3.mid
#   inflating: POP909-087-v4.mid
#   inflating: POP909-088.mid
#   inflating: POP909-088-v1.mid
#   inflating: POP909-088-v2.mid
#   inflating: POP909-088-v3.mid
#   inflating: POP909-088-v4.mid
#   inflating: POP909-088-v5.mid
#   inflating: POP909-090.mid
#   inflating: POP909-090-v1.mid
#   inflating: POP909-090-v2.mid
#   inflating: POP909-090-v3.mid
#   inflating: POP909-091.mid
#   inflating: POP909-091-v1.mid
#   inflating: POP909-091-v2.mid
#   inflating: POP909-091-v3.mid
#   inflating: POP909-095.mid
#   inflating: POP909-095-v1.mid
#   inflating: POP909-095-v2.mid
#   inflating: POP909-095-v3.mid
#   inflating: POP909-095-v4.mid
#   inflating: POP909-096.mid
#   inflating: POP909-096-v1.mid
#   inflating: POP909-096-v2.mid
#   inflating: POP909-096-v3.mid
#   inflating: POP909-096-v4.mid
#   inflating: POP909-097.mid
#   inflating: POP909-097-v1.mid
#   inflating: POP909-097-v2.mid
#   inflating: POP909-097-v3.mid
#   inflating: POP909-098.mid
#   inflating: POP909-098-v1.mid
#   inflating: POP909-099.mid
#   inflating: POP909-099-v1.mid
#   inflating: POP909-099-v2.mid
#   inflating: POP909-099-v3.mid
#   inflating: POP909-099-v4.mid
#   inflating: POP909-099-v5.mid
#   inflating: POP909-099-v6.mid
#   inflating: POP909-099-v7.mid
#   inflating: POP909-099-v8.mid
#   inflating: POP909-100.mid
#   inflating: POP909-100-v1.mid
#   inflating: POP909-100-v2.mid
#   inflating: POP909-102.mid
#   inflating: POP909-102-v1.mid
#   inflating: POP909-103.mid
#   inflating: POP909-103-v1.mid
#   inflating: POP909-103-v2.mid
#   inflating: POP909-103-v3.mid
#   inflating: POP909-103-v4.mid
#   inflating: POP909-104.mid
#   inflating: POP909-104-v1.mid
#   inflating: POP909-105.mid
#   inflating: POP909-105-v1.mid
#   inflating: POP909-105-v2.mid
#   inflating: POP909-105-v3.mid
#   inflating: POP909-106.mid
#   inflating: POP909-106-v1.mid
#   inflating: POP909-106-v2.mid
#   inflating: POP909-106-v3.mid
#   inflating: POP909-106-v4.mid
#   inflating: POP909-108.mid
#   inflating: POP909-108-v1.mid
#   inflating: POP909-108-v2.mid
#   inflating: POP909-108-v3.mid
#   inflating: POP909-108-v4.mid
#   inflating: POP909-109.mid
#   inflating: POP909-109-v1.mid
#   inflating: POP909-111-v1.mid
#   inflating: POP909-111-v2.mid
#   inflating: POP909-111-v3.mid
#   inflating: POP909-111-v4.mid
#   inflating: POP909-111-v5.mid
#   inflating: POP909-111-v6.mid
#   inflating: POP909-112.mid
#   inflating: POP909-112-v1.mid
#   inflating: POP909-112-v2.mid
#   inflating: POP909-113.mid
#   inflating: POP909-113-v1.mid
#   inflating: POP909-113-v2.mid
#   inflating: POP909-113-v3.mid
#   inflating: POP909-113-v4.mid
#   inflating: POP909-115.mid
#   inflating: POP909-115-v1.mid
#   inflating: POP909-115-v2.mid
#   inflating: POP909-115-v3.mid
#   inflating: POP909-115-v4.mid
#   inflating: POP909-117.mid
#   inflating: POP909-117-v1.mid
#   inflating: POP909-117-v2.mid
#   inflating: POP909-119.mid
#   inflating: POP909-119-v1.mid
#   inflating: POP909-119-v2.mid
#   inflating: POP909-119-v3.mid
#   inflating: POP909-119-v4.mid
#   inflating: POP909-120.mid
#   inflating: POP909-120-v1.mid
#   inflating: POP909-120-v2.mid
#   inflating: POP909-120-v3.mid
#   inflating: POP909-121.mid
#   inflating: POP909-121-v1.mid
#   inflating: POP909-121-v2.mid
#   inflating: POP909-121-v3.mid
#   inflating: POP909-122.mid
#   inflating: POP909-122-v1.mid
#   inflating: POP909-122-v2.mid
#   inflating: POP909-122-v3.mid
#   inflating: POP909-122-v4.mid
#   inflating: POP909-123.mid
#   inflating: POP909-125.mid
#   inflating: POP909-125-v1.mid
#   inflating: POP909-128.mid
#   inflating: POP909-128-v1.mid
#   inflating: POP909-129.mid
#   inflating: POP909-129-v1.mid
#   inflating: POP909-130.mid
#   inflating: POP909-130-v1.mid
#   inflating: POP909-131.mid
#   inflating: POP909-134.mid
#   inflating: POP909-134-v1.mid
#   inflating: POP909-134-v2.mid
#   inflating: POP909-134-v3.mid
#   inflating: POP909-135.mid
#   inflating: POP909-136.mid
#   inflating: POP909-138.mid
#   inflating: POP909-138-v1.mid
#   inflating: POP909-142.mid
#   inflating: POP909-142-v1.mid
#   inflating: POP909-142-v2.mid
#   inflating: POP909-143.mid
#   inflating: POP909-143-v1.mid
#   inflating: POP909-143-v2.mid
#   inflating: POP909-144.mid
#   inflating: POP909-144-v1.mid
#   inflating: POP909-144-v2.mid
#   inflating: POP909-144-v3.mid
#   inflating: POP909-144-v4.mid
#   inflating: POP909-144-v5.mid
#   inflating: POP909-148.mid
#   inflating: POP909-148-v1.mid
#   inflating: POP909-148-v2.mid
#   inflating: POP909-148-v3.mid
#   inflating: POP909-150.mid
#   inflating: POP909-150-v1.mid
#   inflating: POP909-150-v2.mid
#   inflating: POP909-150-v3.mid
#   inflating: POP909-151.mid
#   inflating: POP909-151-v1.mid
#   inflating: POP909-151-v2.mid
#   inflating: POP909-152.mid
#   inflating: POP909-152-v1.mid
#   inflating: POP909-152-v2.mid
#   inflating: POP909-153.mid
#   inflating: POP909-153-v1.mid
#   inflating: POP909-155.mid
#   inflating: POP909-155-v1.mid
#   inflating: POP909-156.mid
#   inflating: POP909-156-v1.mid
#   inflating: POP909-156-v2.mid
#   inflating: POP909-157.mid
#   inflating: POP909-157-v1.mid
#   inflating: POP909-157-v2.mid
#   inflating: POP909-157-v3.mid
#   inflating: POP909-157-v4.mid
#   inflating: POP909-159.mid
#   inflating: POP909-160.mid
#   inflating: POP909-160-v1.mid
#   inflating: POP909-160-v2.mid
#   inflating: POP909-160-v3.mid
#   inflating: POP909-161.mid
#   inflating: POP909-161-v1.mid
#   inflating: POP909-161-v2.mid
#   inflating: POP909-163.mid
#   inflating: POP909-163-v1.mid
#   inflating: POP909-164.mid
#   inflating: POP909-164-v1.mid
#   inflating: POP909-164-v2.mid
#   inflating: POP909-165.mid
#   inflating: POP909-165-v1.mid
#   inflating: POP909-166.mid
#   inflating: POP909-166-v1.mid
#   inflating: POP909-167.mid
#   inflating: POP909-167-v1.mid
#   inflating: POP909-168.mid
#   inflating: POP909-168-v1.mid
#   inflating: POP909-168-v2.mid
#   inflating: POP909-169.mid
#   inflating: POP909-169-v1.mid
#   inflating: POP909-169-v2.mid
#   inflating: POP909-170.mid
#   inflating: POP909-170-v1.mid
#   inflating: POP909-171.mid
#   inflating: POP909-171-v1.mid
#   inflating: POP909-173.mid
#   inflating: POP909-173-v1.mid
#   inflating: POP909-173-v2.mid
#   inflating: POP909-174.mid
#   inflating: POP909-174-v1.mid
#   inflating: POP909-174-v2.mid
#   inflating: POP909-179.mid
#   inflating: POP909-179-v1.mid
#   inflating: POP909-180.mid
#   inflating: POP909-180-v1.mid
#   inflating: POP909-180-v2.mid
#   inflating: POP909-181.mid
#   inflating: POP909-181-v1.mid
#   inflating: POP909-181-v2.mid
#   inflating: POP909-183.mid
#   inflating: POP909-183-v1.mid
#   inflating: POP909-183-v2.mid
#   inflating: POP909-184.mid
#   inflating: POP909-184-v1.mid
#   inflating: POP909-184-v2.mid
#   inflating: POP909-187.mid
#   inflating: POP909-187-v1.mid
#   inflating: POP909-187-v2.mid
#   inflating: POP909-188.mid
#   inflating: POP909-188-v1.mid
#   inflating: POP909-188-v2.mid
#   inflating: POP909-189.mid
#   inflating: POP909-189-v1.mid
#   inflating: POP909-190.mid
#   inflating: POP909-190-v1.mid
#   inflating: POP909-190-v2.mid
#   inflating: POP909-191.mid
#   inflating: POP909-191-v1.mid
#   inflating: POP909-191-v2.mid
#   inflating: POP909-192.mid
#   inflating: POP909-192-v1.mid
#   inflating: POP909-192-v2.mid
#   inflating: POP909-192-v3.mid
#   inflating: POP909-193.mid
#   inflating: POP909-193-v1.mid
#   inflating: POP909-196.mid
#   inflating: POP909-196-v1.mid
#   inflating: POP909-196-v2.mid
#   inflating: POP909-196-v3.mid
#   inflating: POP909-197.mid
#   inflating: POP909-197-v1.mid
#   inflating: POP909-197-v2.mid
#   inflating: POP909-199.mid
#   inflating: POP909-199-v1.mid
#   inflating: POP909-199-v2.mid
#   inflating: POP909-200.mid
#   inflating: POP909-200-v1.mid
#   inflating: POP909-200-v2.mid
#   inflating: POP909-200-v3.mid
#   inflating: POP909-200-v4.mid
#   inflating: POP909-201.mid
#   inflating: POP909-201-v1.mid
#   inflating: POP909-201-v2.mid
#   inflating: POP909-202.mid
#   inflating: POP909-202-v1.mid
#   inflating: POP909-203.mid
#   inflating: POP909-203-v1.mid
#   inflating: POP909-203-v2.mid
#   inflating: POP909-204.mid
#   inflating: POP909-204-v1.mid
#   inflating: POP909-204-v2.mid
#   inflating: POP909-205.mid
#   inflating: POP909-205-v1.mid
#   inflating: POP909-205-v2.mid
#   inflating: POP909-207.mid
#   inflating: POP909-207-v1.mid
#   inflating: POP909-211.mid
#   inflating: POP909-211-v1.mid
#   inflating: POP909-211-v2.mid
#   inflating: POP909-211-v3.mid
#   inflating: POP909-211-v4.mid
#   inflating: POP909-211-v5.mid
#   inflating: POP909-212.mid
#   inflating: POP909-212-v1.mid
#   inflating: POP909-212-v2.mid
#   inflating: POP909-213-v1.mid
#   inflating: POP909-214.mid
#   inflating: POP909-214-v1.mid
#   inflating: POP909-214-v2.mid
#   inflating: POP909-214-v3.mid
#   inflating: POP909-214-v4.mid
#   inflating: POP909-215.mid
#   inflating: POP909-215-v1.mid
#   inflating: POP909-217.mid
#   inflating: POP909-217-v1.mid
#   inflating: POP909-217-v2.mid
#   inflating: POP909-220.mid
#   inflating: POP909-220-v1.mid
#   inflating: POP909-220-v2.mid
#   inflating: POP909-223.mid
#   inflating: POP909-223-v1.mid
#   inflating: POP909-229.mid
#   inflating: POP909-229-v1.mid
#   inflating: POP909-229-v2.mid
#   inflating: POP909-231.mid
#   inflating: POP909-231-v1.mid
#   inflating: POP909-231-v2.mid
#   inflating: POP909-234.mid
#   inflating: POP909-236.mid
#   inflating: POP909-236-v1.mid
#   inflating: POP909-240.mid
#   inflating: POP909-240-v1.mid
#   inflating: POP909-248.mid
#   inflating: POP909-248-v1.mid
#   inflating: POP909-249.mid
#   inflating: POP909-249-v1.mid
#   inflating: POP909-250.mid
#   inflating: POP909-250-v1.mid
#   inflating: POP909-250-v2.mid
#   inflating: POP909-251.mid
#   inflating: POP909-251-v1.mid
#   inflating: POP909-253.mid
#   inflating: POP909-253-v1.mid
#   inflating: POP909-255.mid
#   inflating: POP909-255-v1.mid
#   inflating: POP909-255-v2.mid
#   inflating: POP909-258.mid
#   inflating: POP909-258-v1.mid
#   inflating: POP909-258-v2.mid
#   inflating: POP909-259.mid
#   inflating: POP909-259-v1.mid
#   inflating: POP909-259-v2.mid
#   inflating: POP909-259-v3.mid
#   inflating: POP909-260.mid
#   inflating: POP909-260-v1.mid
#   inflating: POP909-260-v2.mid
#   inflating: POP909-260-v3.mid
#   inflating: POP909-260-v4.mid
#   inflating: POP909-261.mid
#   inflating: POP909-261-v1.mid
#   inflating: POP909-261-v2.mid
#   inflating: POP909-262.mid
#   inflating: POP909-262-v1.mid
#   inflating: POP909-262-v2.mid
#   inflating: POP909-263.mid
#   inflating: POP909-263-v1.mid
#   inflating: POP909-265.mid
#   inflating: POP909-265-v1.mid
#   inflating: POP909-265-v2.mid
#   inflating: POP909-267.mid
#   inflating: POP909-267-v1.mid
#   inflating: POP909-267-v2.mid
#   inflating: POP909-267-v3.mid
#   inflating: POP909-267-v4.mid
#   inflating: POP909-267-v5.mid
#   inflating: POP909-268.mid
#   inflating: POP909-268-v1.mid
#   inflating: POP909-268-v2.mid
#   inflating: POP909-269.mid
#   inflating: POP909-269-v1.mid
#   inflating: POP909-269-v2.mid
#   inflating: POP909-269-v3.mid
#   inflating: POP909-270.mid
#   inflating: POP909-270-v1.mid
#   inflating: POP909-271.mid
#   inflating: POP909-271-v1.mid
#   inflating: POP909-271-v2.mid
#   inflating: POP909-272.mid
#   inflating: POP909-272-v1.mid
#   inflating: POP909-272-v2.mid
#   inflating: POP909-273.mid
#   inflating: POP909-273-v1.mid
#   inflating: POP909-273-v2.mid
#   inflating: POP909-273-v3.mid
#   inflating: POP909-273-v4.mid
#   inflating: POP909-274.mid
#   inflating: POP909-274-v1.mid
#   inflating: POP909-274-v2.mid
#   inflating: POP909-274-v3.mid
#   inflating: POP909-274-v4.mid
#   inflating: POP909-275.mid
#   inflating: POP909-275-v1.mid
#   inflating: POP909-275-v2.mid
#   inflating: POP909-276.mid
#   inflating: POP909-276-v1.mid
#   inflating: POP909-276-v2.mid
#   inflating: POP909-278.mid
#   inflating: POP909-278-v1.mid
#   inflating: POP909-278-v2.mid
#   inflating: POP909-278-v3.mid
#   inflating: POP909-278-v4.mid
#   inflating: POP909-279.mid
#   inflating: POP909-279-v1.mid
#   inflating: POP909-279-v2.mid
#   inflating: POP909-279-v3.mid
#   inflating: POP909-279-v4.mid
#   inflating: POP909-281.mid
#   inflating: POP909-281-v1.mid
#   inflating: POP909-281-v2.mid
#   inflating: POP909-282.mid
#   inflating: POP909-282-v1.mid
#   inflating: POP909-282-v2.mid
#   inflating: POP909-282-v3.mid
#   inflating: POP909-282-v4.mid
#   inflating: POP909-283.mid
#   inflating: POP909-283-v1.mid
#   inflating: POP909-284.mid
#   inflating: POP909-284-v1.mid
#   inflating: POP909-284-v2.mid
#   inflating: POP909-284-v3.mid
#   inflating: POP909-285.mid
#   inflating: POP909-285-v1.mid
#   inflating: POP909-285-v2.mid
#   inflating: POP909-285-v3.mid
#   inflating: POP909-285-v4.mid
#   inflating: POP909-286.mid
#   inflating: POP909-286-v1.mid
#   inflating: POP909-286-v2.mid
#   inflating: POP909-287.mid
#   inflating: POP909-287-v1.mid
#   inflating: POP909-287-v2.mid
#   inflating: POP909-287-v3.mid
#   inflating: POP909-288.mid
#   inflating: POP909-290.mid
#   inflating: POP909-290-v1.mid
#   inflating: POP909-290-v2.mid
#   inflating: POP909-291.mid
#   inflating: POP909-291-v1.mid
#   inflating: POP909-291-v2.mid
#   inflating: POP909-292.mid
#   inflating: POP909-292-v2.mid
#   inflating: POP909-293.mid
#   inflating: POP909-293-v1.mid
#   inflating: POP909-293-v2.mid
#   inflating: POP909-293-v3.mid
#   inflating: POP909-294.mid
#   inflating: POP909-294-v1.mid
#   inflating: POP909-296.mid
#   inflating: POP909-296-v1.mid
#   inflating: POP909-296-v2.mid
#   inflating: POP909-297.mid
#   inflating: POP909-297-v1.mid
#   inflating: POP909-297-v2.mid
#   inflating: POP909-298.mid
#   inflating: POP909-298-v1.mid
#   inflating: POP909-298-v2.mid
#   inflating: POP909-299.mid
#   inflating: POP909-299-v1.mid
#   inflating: POP909-299-v2.mid
#   inflating: POP909-300-v1.mid
#   inflating: POP909-300-v2.mid
#   inflating: POP909-301.mid
#   inflating: POP909-301-v1.mid
#   inflating: POP909-301-v2.mid
#   inflating: POP909-301-v3.mid
#   inflating: POP909-301-v4.mid
#   inflating: POP909-302.mid
#   inflating: POP909-302-v1.mid
#   inflating: POP909-303.mid
#   inflating: POP909-303-v1.mid
#   inflating: POP909-304.mid
#   inflating: POP909-304-v1.mid
#   inflating: POP909-304-v2.mid
#   inflating: POP909-304-v3.mid
#   inflating: POP909-304-v4.mid
#   inflating: POP909-304-v5.mid
#   inflating: POP909-304-v6.mid
#   inflating: POP909-304-v7.mid
#   inflating: POP909-304-v8.mid
#   inflating: POP909-305.mid
#   inflating: POP909-305-v1.mid
#   inflating: POP909-305-v2.mid
#   inflating: POP909-305-v3.mid
#   inflating: POP909-306.mid
#   inflating: POP909-306-v1.mid
#   inflating: POP909-306-v2.mid
#   inflating: POP909-307.mid
#   inflating: POP909-307-v1.mid
#   inflating: POP909-308.mid
#   inflating: POP909-308-v1.mid
#   inflating: POP909-308-v2.mid
#   inflating: POP909-308-v3.mid
#   inflating: POP909-310.mid
#   inflating: POP909-310-v1.mid
#   inflating: POP909-311.mid
#   inflating: POP909-311-v1.mid
#   inflating: POP909-311-v2.mid
#   inflating: POP909-312.mid
#   inflating: POP909-312-v1.mid
#   inflating: POP909-313.mid
#   inflating: POP909-313-v1.mid
#   inflating: POP909-313-v2.mid
#   inflating: POP909-313-v3.mid
#   inflating: POP909-314.mid
#   inflating: POP909-314-v1.mid
#   inflating: POP909-315.mid
#   inflating: POP909-315-v1.mid
#   inflating: POP909-315-v2.mid
#   inflating: POP909-317.mid
#   inflating: POP909-317-v1.mid
#   inflating: POP909-318.mid
#   inflating: POP909-318-v1.mid
#   inflating: POP909-318-v2.mid
#   inflating: POP909-319.mid
#   inflating: POP909-319-v1.mid
#   inflating: POP909-321.mid
#   inflating: POP909-321-v1.mid
#   inflating: POP909-322.mid
#   inflating: POP909-322-v1.mid
#   inflating: POP909-323.mid
#   inflating: POP909-323-v1.mid
#   inflating: POP909-323-v2.mid
#   inflating: POP909-323-v3.mid
#   inflating: POP909-324.mid
#   inflating: POP909-324-v1.mid
#   inflating: POP909-324-v2.mid
#   inflating: POP909-324-v4.mid
#   inflating: POP909-325.mid
#   inflating: POP909-325-v1.mid
#   inflating: POP909-325-v2.mid
#   inflating: POP909-325-v3.mid
#   inflating: POP909-325-v4.mid
#   inflating: POP909-326.mid
#   inflating: POP909-326-v1.mid
#   inflating: POP909-326-v2.mid
#   inflating: POP909-327.mid
#   inflating: POP909-327-v1.mid
#   inflating: POP909-327-v2.mid
#   inflating: POP909-328.mid
#   inflating: POP909-328-v1.mid
#   inflating: POP909-329.mid
#   inflating: POP909-329-v1.mid
#   inflating: POP909-329-v2.mid
#   inflating: POP909-329-v3.mid
#   inflating: POP909-329-v4.mid
#   inflating: POP909-330.mid
#   inflating: POP909-330-v1.mid
#   inflating: POP909-330-v2.mid
#   inflating: POP909-331-v1.mid
#   inflating: POP909-331-v2.mid
#   inflating: POP909-331-v3.mid
#   inflating: POP909-332.mid
#   inflating: POP909-332-v1.mid
#   inflating: POP909-334.mid
#   inflating: POP909-334-v1.mid
#   inflating: POP909-334-v2.mid
#   inflating: POP909-335.mid
#   inflating: POP909-335-v1.mid
#   inflating: POP909-335-v2.mid
#   inflating: POP909-335-v3.mid
#   inflating: POP909-335-v4.mid
#   inflating: POP909-336.mid
#   inflating: POP909-336-v1.mid
#   inflating: POP909-336-v2.mid
#   inflating: POP909-336-v3.mid
#   inflating: POP909-337.mid
#   inflating: POP909-337-v1.mid
#   inflating: POP909-337-v2.mid
#   inflating: POP909-338.mid
#   inflating: POP909-338-v1.mid
#   inflating: POP909-339.mid
#   inflating: POP909-339-v1.mid
#   inflating: POP909-339-v2.mid
#   inflating: POP909-339-v3.mid
#   inflating: POP909-340.mid
#   inflating: POP909-340-v1.mid
#   inflating: POP909-340-v2.mid
#   inflating: POP909-340-v3.mid
#   inflating: POP909-341.mid
#   inflating: POP909-341-v1.mid
#   inflating: POP909-341-v2.mid
#   inflating: POP909-341-v3.mid
#   inflating: POP909-342.mid
#   inflating: POP909-342-v1.mid
#   inflating: POP909-342-v2.mid
#   inflating: POP909-342-v3.mid
#   inflating: POP909-343.mid
#   inflating: POP909-343-v1.mid
#   inflating: POP909-343-v2.mid
#   inflating: POP909-345.mid
#   inflating: POP909-345-v1.mid
#   inflating: POP909-345-v2.mid
#   inflating: POP909-346.mid
#   inflating: POP909-346-v1.mid
#   inflating: POP909-347.mid
#   inflating: POP909-347-v1.mid
#   inflating: POP909-347-v2.mid
#   inflating: POP909-348.mid
#   inflating: POP909-348-v1.mid
#   inflating: POP909-348-v2.mid
#   inflating: POP909-349.mid
#   inflating: POP909-349-v1.mid
#   inflating: POP909-349-v2.mid
#   inflating: POP909-350.mid
#   inflating: POP909-350-v1.mid
#   inflating: POP909-350-v2.mid
#   inflating: POP909-350-v3.mid
#   inflating: POP909-350-v4.mid
#   inflating: POP909-351.mid
#   inflating: POP909-351-v1.mid
#   inflating: POP909-351-v2.mid
#   inflating: POP909-352.mid
#   inflating: POP909-352-v1.mid
#   inflating: POP909-352-v2.mid
#   inflating: POP909-352-v3.mid
#   inflating: POP909-352-v4.mid
#   inflating: POP909-353.mid
#   inflating: POP909-353-v1.mid
#   inflating: POP909-353-v2.mid
#   inflating: POP909-355.mid
#   inflating: POP909-355-v1.mid
#   inflating: POP909-356.mid
#   inflating: POP909-356-v1.mid
#   inflating: POP909-357.mid
#   inflating: POP909-357-v1.mid
#   inflating: POP909-358.mid
#   inflating: POP909-358-v1.mid
#   inflating: POP909-359.mid
#   inflating: POP909-359-v1.mid
#   inflating: POP909-360.mid
#   inflating: POP909-360-v1.mid
#   inflating: POP909-360-v2.mid
#   inflating: POP909-361.mid
#   inflating: POP909-361-v1.mid
#   inflating: POP909-362.mid
#   inflating: POP909-362-v4.mid
#   inflating: POP909-363.mid
#   inflating: POP909-363-v1.mid
#   inflating: POP909-364.mid
#   inflating: POP909-364-v1.mid
#   inflating: POP909-365.mid
#   inflating: POP909-365-v1.mid
#   inflating: POP909-365-v2.mid
#   inflating: POP909-365-v3.mid
#   inflating: POP909-367.mid
#   inflating: POP909-367-v1.mid
#   inflating: POP909-367-v2.mid
#   inflating: POP909-367-v3.mid
#   inflating: POP909-367-v4.mid
#   inflating: POP909-367-v5.mid
#   inflating: POP909-368.mid
#   inflating: POP909-368-v1.mid
#   inflating: POP909-368-v2.mid
#   inflating: POP909-368-v3.mid
#   inflating: POP909-370.mid
#   inflating: POP909-370-v1.mid
#   inflating: POP909-371.mid
#   inflating: POP909-371-v1.mid
#   inflating: POP909-374.mid
#   inflating: POP909-374-v1.mid
#   inflating: POP909-374-v2.mid
#   inflating: POP909-375-v1.mid
#   inflating: POP909-375-v2.mid
#   inflating: POP909-375-v4.mid
#   inflating: POP909-376.mid
#   inflating: POP909-376-v1.mid
#   inflating: POP909-376-v2.mid
#   inflating: POP909-376-v3.mid
#   inflating: POP909-376-v4.mid
#   inflating: POP909-377.mid
#   inflating: POP909-377-v1.mid
#   inflating: POP909-377-v2.mid
#   inflating: POP909-378.mid
#   inflating: POP909-378-v1.mid
#   inflating: POP909-378-v2.mid
#   inflating: POP909-378-v3.mid
#   inflating: POP909-379.mid
#   inflating: POP909-379-v1.mid
#   inflating: POP909-380.mid
#   inflating: POP909-380-v1.mid
#   inflating: POP909-381.mid
#   inflating: POP909-381-v1.mid
#   inflating: POP909-382.mid
#   inflating: POP909-382-v1.mid
#   inflating: POP909-382-v2.mid
#   inflating: POP909-382-v3.mid
#   inflating: POP909-383.mid
#   inflating: POP909-383-v1.mid
#   inflating: POP909-383-v2.mid
#   inflating: POP909-383-v3.mid
#   inflating: POP909-383-v4.mid
#   inflating: POP909-384.mid
#   inflating: POP909-384-v1.mid
#   inflating: POP909-385.mid
#   inflating: POP909-385-v1.mid
#   inflating: POP909-386.mid
#   inflating: POP909-386-v1.mid
#   inflating: POP909-388.mid
#   inflating: POP909-388-v1.mid
#   inflating: POP909-389.mid
#   inflating: POP909-389-v1.mid
#   inflating: POP909-390.mid
#   inflating: POP909-390-v1.mid
#   inflating: POP909-390-v2.mid
#   inflating: POP909-391.mid
#   inflating: POP909-391-v1.mid
#   inflating: POP909-391-v2.mid
#   inflating: POP909-391-v3.mid
#   inflating: POP909-392.mid
#   inflating: POP909-392-v1.mid
#   inflating: POP909-392-v2.mid
#   inflating: POP909-392-v3.mid
#   inflating: POP909-392-v4.mid
#   inflating: POP909-392-v5.mid
#   inflating: POP909-392-v6.mid
#   inflating: POP909-392-v7.mid
#   inflating: POP909-392-v8.mid
#   inflating: POP909-392-v9.mid
#   inflating: POP909-394.mid
#   inflating: POP909-394-v1.mid
#   inflating: POP909-395.mid
#   inflating: POP909-395-v1.mid
#   inflating: POP909-397.mid
#   inflating: POP909-397-v1.mid
#   inflating: POP909-398.mid
#   inflating: POP909-398-v1.mid
#   inflating: POP909-398-v2.mid
#   inflating: POP909-398-v3.mid
#   inflating: POP909-399.mid
#   inflating: POP909-399-v1.mid
#   inflating: POP909-400.mid
#   inflating: POP909-400-v1.mid
#   inflating: POP909-401.mid
#   inflating: POP909-401-v1.mid
#   inflating: POP909-403.mid
#   inflating: POP909-403-v1.mid
#   inflating: POP909-404.mid
#   inflating: POP909-404-v1.mid
#   inflating: POP909-406.mid
#   inflating: POP909-406-v1.mid
#   inflating: POP909-407.mid
#   inflating: POP909-407-v2.mid
#   inflating: POP909-409.mid
#   inflating: POP909-409-v1.mid
#   inflating: POP909-409-v2.mid
#   inflating: POP909-409-v3.mid
#   inflating: POP909-410.mid
#   inflating: POP909-410-v1.mid
#   inflating: POP909-410-v2.mid
#   inflating: POP909-411.mid
#   inflating: POP909-411-v1.mid
#   inflating: POP909-411-v2.mid
#   inflating: POP909-414.mid
#   inflating: POP909-414-v1.mid
#   inflating: POP909-415.mid
#   inflating: POP909-415-v1.mid
#   inflating: POP909-416.mid
#   inflating: POP909-416-v1.mid
#   inflating: POP909-419.mid
#   inflating: POP909-419-v1.mid
#   inflating: POP909-420.mid
#   inflating: POP909-421.mid
#   inflating: POP909-421-v1.mid
#   inflating: POP909-421-v2.mid
#   inflating: POP909-421-v3.mid
#   inflating: POP909-422.mid
#   inflating: POP909-422-v1.mid
#   inflating: POP909-424.mid
#   inflating: POP909-424-v1.mid
#   inflating: POP909-424-v2.mid
#   inflating: POP909-425.mid
#   inflating: POP909-425-v1.mid
#   inflating: POP909-425-v2.mid
#   inflating: POP909-425-v3.mid
#   inflating: POP909-425-v4.mid
#   inflating: POP909-425-v5.mid
#   inflating: POP909-425-v6.mid
#   inflating: POP909-427.mid
#   inflating: POP909-427-v1.mid
#   inflating: POP909-427-v2.mid
#   inflating: POP909-428.mid
#   inflating: POP909-428-v1.mid
#   inflating: POP909-429.mid
#   inflating: POP909-429-v1.mid
#   inflating: POP909-430.mid
#   inflating: POP909-430-v1.mid
#   inflating: POP909-433.mid
#   inflating: POP909-433-v1.mid
#   inflating: POP909-435.mid
#   inflating: POP909-435-v1.mid
#   inflating: POP909-435-v2.mid
#   inflating: POP909-436.mid
#   inflating: POP909-436-v1.mid
#   inflating: POP909-436-v2.mid
#   inflating: POP909-442.mid
#   inflating: POP909-443.mid
#   inflating: POP909-443-v1.mid
#   inflating: POP909-444.mid
#   inflating: POP909-444-v1.mid
#   inflating: POP909-444-v2.mid
#   inflating: POP909-445.mid
#   inflating: POP909-445-v1.mid
#   inflating: POP909-446.mid
#   inflating: POP909-446-v1.mid
#   inflating: POP909-446-v2.mid
#   inflating: POP909-447.mid
#   inflating: POP909-447-v1.mid
#   inflating: POP909-447-v2.mid
#   inflating: POP909-448.mid
#   inflating: POP909-448-v1.mid
#   inflating: POP909-448-v2.mid
#   inflating: POP909-449.mid
#   inflating: POP909-449-v1.mid
#   inflating: POP909-449-v2.mid
#   inflating: POP909-449-v3.mid
#   inflating: POP909-450.mid
#   inflating: POP909-450-v1.mid
#   inflating: POP909-450-v2.mid
#   inflating: POP909-450-v3.mid
#   inflating: POP909-450-v4.mid
#   inflating: POP909-451.mid
#   inflating: POP909-451-v1.mid
#   inflating: POP909-454.mid
#   inflating: POP909-454-v1.mid
#   inflating: POP909-454-v2.mid
#   inflating: POP909-454-v3.mid
#   inflating: POP909-454-v4.mid
#   inflating: POP909-454-v5.mid
#   inflating: POP909-454-v6.mid
#   inflating: POP909-458.mid
#   inflating: POP909-458-v1.mid
#   inflating: POP909-458-v2.mid
#   inflating: POP909-458-v3.mid
#   inflating: POP909-460.mid
#   inflating: POP909-460-v1.mid
#   inflating: POP909-461.mid
#   inflating: POP909-461-v1.mid
#   inflating: POP909-461-v2.mid
#   inflating: POP909-463.mid
#   inflating: POP909-463-v1.mid
#   inflating: POP909-463-v2.mid
#   inflating: POP909-464.mid
#   inflating: POP909-464-v1.mid
#   inflating: POP909-464-v2.mid
#   inflating: POP909-465.mid
#   inflating: POP909-465-v1.mid
#   inflating: POP909-465-v2.mid
#   inflating: POP909-465-v3.mid
#   inflating: POP909-466.mid
#   inflating: POP909-466-v1.mid
#   inflating: POP909-467.mid
#   inflating: POP909-467-v1.mid
#   inflating: POP909-469.mid
#   inflating: POP909-469-v1.mid
#   inflating: POP909-472.mid
#   inflating: POP909-472-v1.mid
#   inflating: POP909-472-v2.mid
#   inflating: POP909-472-v3.mid
#   inflating: POP909-473.mid
#   inflating: POP909-473-v1.mid
#   inflating: POP909-474.mid
#   inflating: POP909-474-v1.mid
#   inflating: POP909-475.mid
#   inflating: POP909-475-v1.mid
#   inflating: POP909-475-v2.mid
#   inflating: POP909-476.mid
#   inflating: POP909-476-v1.mid
#   inflating: POP909-477.mid
#   inflating: POP909-477-v1.mid
#   inflating: POP909-478.mid
#   inflating: POP909-478-v1.mid
#   inflating: POP909-478-v2.mid
#   inflating: POP909-478-v3.mid
#   inflating: POP909-478-v4.mid
#   inflating: POP909-479.mid
#   inflating: POP909-479-v1.mid
#   inflating: POP909-480.mid
#   inflating: POP909-480-v1.mid
#   inflating: POP909-481.mid
#   inflating: POP909-481-v1.mid
#   inflating: POP909-482.mid
#   inflating: POP909-482-v1.mid
#   inflating: POP909-482-v2.mid
#   inflating: POP909-483.mid
#   inflating: POP909-483-v1.mid
#   inflating: POP909-486.mid
#   inflating: POP909-486-v1.mid
#   inflating: POP909-488.mid
#   inflating: POP909-488-v1.mid
#   inflating: POP909-489.mid
#   inflating: POP909-489-v1.mid
#   inflating: POP909-490.mid
#   inflating: POP909-490-v1.mid
#   inflating: POP909-490-v2.mid
#   inflating: POP909-490-v3.mid
#   inflating: POP909-490-v4.mid
#   inflating: POP909-491-v2.mid
#   inflating: POP909-492.mid
#   inflating: POP909-492-v1.mid
#   inflating: POP909-493.mid
#   inflating: POP909-493-v1.mid
#   inflating: POP909-493-v2.mid
#   inflating: POP909-493-v3.mid
#   inflating: POP909-493-v4.mid
#   inflating: POP909-494.mid
#   inflating: POP909-494-v1.mid
#   inflating: POP909-495.mid
#   inflating: POP909-495-v1.mid
#   inflating: POP909-496.mid
#   inflating: POP909-496-v1.mid
#   inflating: POP909-497.mid
#   inflating: POP909-498.mid
#   inflating: POP909-498-v1.mid
#   inflating: POP909-501.mid
#   inflating: POP909-501-v1.mid
#   inflating: POP909-501-v2.mid
#   inflating: POP909-502.mid
#   inflating: POP909-502-v1.mid
#   inflating: POP909-502-v2.mid
#   inflating: POP909-502-v3.mid
#   inflating: POP909-503.mid
#   inflating: POP909-503-v1.mid
#   inflating: POP909-504.mid
#   inflating: POP909-504-v1.mid
#   inflating: POP909-505.mid
#   inflating: POP909-505-v1.mid
#   inflating: POP909-505-v2.mid
#   inflating: POP909-505-v3.mid
#   inflating: POP909-507.mid
#   inflating: POP909-507-v1.mid
#   inflating: POP909-507-v2.mid
#   inflating: POP909-509.mid
#   inflating: POP909-509-v1.mid
#   inflating: POP909-509-v2.mid
#   inflating: POP909-509-v3.mid
#   inflating: POP909-509-v4.mid
#   inflating: POP909-514.mid
#   inflating: POP909-514-v1.mid
#   inflating: POP909-514-v2.mid
#   inflating: POP909-514-v3.mid
#   inflating: POP909-515.mid
#   inflating: POP909-516.mid
#   inflating: POP909-516-v1.mid
#   inflating: POP909-516-v2.mid
#   inflating: POP909-517.mid
#   inflating: POP909-517-v1.mid
#   inflating: POP909-518.mid
#   inflating: POP909-518-v1.mid
#   inflating: POP909-520.mid
#   inflating: POP909-520-v1.mid
#   inflating: POP909-520-v2.mid
#   inflating: POP909-520-v3.mid
#   inflating: POP909-521.mid
#   inflating: POP909-521-v1.mid
#   inflating: POP909-522.mid
#   inflating: POP909-522-v1.mid
#   inflating: POP909-523.mid
#   inflating: POP909-523-v1.mid
#   inflating: POP909-525.mid
#   inflating: POP909-525-v1.mid
#   inflating: POP909-525-v2.mid
#   inflating: POP909-525-v3.mid
#   inflating: POP909-525-v4.mid
#   inflating: POP909-529.mid
#   inflating: POP909-529-v1.mid
#   inflating: POP909-529-v2.mid
#   inflating: POP909-531.mid
#   inflating: POP909-531-v1.mid
#   inflating: POP909-532.mid
#   inflating: POP909-532-v1.mid
#   inflating: POP909-532-v2.mid
#   inflating: POP909-532-v3.mid
#   inflating: POP909-532-v4.mid
#   inflating: POP909-533.mid
#   inflating: POP909-533-v1.mid
#   inflating: POP909-534.mid
#   inflating: POP909-534-v1.mid
#   inflating: POP909-535.mid
#   inflating: POP909-535-v1.mid
#   inflating: POP909-537.mid
#   inflating: POP909-537-v1.mid
#   inflating: POP909-537-v2.mid
#   inflating: POP909-538.mid
#   inflating: POP909-538-v1.mid
#   inflating: POP909-538-v2.mid
#   inflating: POP909-539.mid
#   inflating: POP909-539-v1.mid
#   inflating: POP909-540.mid
#   inflating: POP909-540-v1.mid
#   inflating: POP909-542.mid
#   inflating: POP909-542-v1.mid
#   inflating: POP909-542-v2.mid
#   inflating: POP909-542-v3.mid
#   inflating: POP909-542-v4.mid
#   inflating: POP909-543.mid
#   inflating: POP909-543-v1.mid
#   inflating: POP909-543-v2.mid
#   inflating: POP909-546.mid
#   inflating: POP909-546-v1.mid
#   inflating: POP909-546-v2.mid
#   inflating: POP909-547.mid
#   inflating: POP909-547-v1.mid
#   inflating: POP909-547-v2.mid
#   inflating: POP909-549.mid
#   inflating: POP909-549-v1.mid
#   inflating: POP909-549-v2.mid
#   inflating: POP909-549-v3.mid
#   inflating: POP909-549-v4.mid
#   inflating: POP909-549-v5.mid
#   inflating: POP909-550.mid
#   inflating: POP909-550-v1.mid
#   inflating: POP909-550-v2.mid
#   inflating: POP909-550-v3.mid
#   inflating: POP909-550-v4.mid
#   inflating: POP909-551.mid
#   inflating: POP909-551-v1.mid
#   inflating: POP909-551-v2.mid
#   inflating: POP909-552.mid
#   inflating: POP909-552-v1.mid
#   inflating: POP909-552-v2.mid
#   inflating: POP909-552-v3.mid
#   inflating: POP909-552-v4.mid
#   inflating: POP909-553.mid
#   inflating: POP909-553-v1.mid
#   inflating: POP909-554.mid
# ...
#   inflating: POP909-733.mid
#   inflating: POP909-733-v1.mid
#   inflating: POP909-734.mid
#   inflating: POP909-734-v1.mid
#   inflating: POP909-735.mid
#   inflating: POP909-735-v1.mid
#   inflating: POP909-735-v2.mid
#   inflating: POP909-736.mid
#   inflating: POP909-736-v1.mid
#   inflating: POP909-736-v2.mid
#   inflating: POP909-736-v3.mid
#   inflating: POP909-736-v4.mid
#   inflating: POP909-739.mid
#   inflating: POP909-739-v1.mid
#   inflating: POP909-739-v2.mid
#   inflating: POP909-739-v3.mid
#   inflating: POP909-741.mid
#   inflating: POP909-741-v1.mid
#   inflating: POP909-741-v2.mid
#   inflating: POP909-741-v3.mid
#   inflating: POP909-742.mid
#   inflating: POP909-742-v1.mid
#   inflating: POP909-744.mid
#   inflating: POP909-744-v1.mid
#   inflating: POP909-744-v2.mid
#   inflating: POP909-744-v3.mid
#   inflating: POP909-745.mid
#   inflating: POP909-745-v1.mid
#   inflating: POP909-745-v2.mid
#   inflating: POP909-745-v3.mid
#   inflating: POP909-746.mid
#   inflating: POP909-746-v1.mid
#   inflating: POP909-747.mid
#   inflating: POP909-747-v1.mid
#   inflating: POP909-748.mid
#   inflating: POP909-748-v1.mid
#   inflating: POP909-748-v2.mid
#   inflating: POP909-748-v3.mid
#   inflating: POP909-749.mid
#   inflating: POP909-749-v1.mid
#   inflating: POP909-750.mid
#   inflating: POP909-750-v1.mid
#   inflating: POP909-751.mid
#   inflating: POP909-751-v1.mid
#   inflating: POP909-751-v2.mid
#   inflating: POP909-752.mid
#   inflating: POP909-752-v1.mid
#   inflating: POP909-752-v2.mid
#   inflating: POP909-754.mid
#   inflating: POP909-754-v1.mid
#   inflating: POP909-754-v2.mid
#   inflating: POP909-754-v3.mid
#   inflating: POP909-754-v4.mid
#   inflating: POP909-754-v5.mid
#   inflating: POP909-755.mid
#   inflating: POP909-755-v1.mid
#   inflating: POP909-755-v2.mid
#   inflating: POP909-755-v3.mid
#   inflating: POP909-756.mid
#   inflating: POP909-756-v1.mid
#   inflating: POP909-756-v2.mid
#   inflating: POP909-758.mid
#   inflating: POP909-758-v1.mid
#   inflating: POP909-758-v2.mid
#   inflating: POP909-759.mid
#   inflating: POP909-759-v1.mid
#   inflating: POP909-759-v2.mid
#   inflating: POP909-760.mid
#   inflating: POP909-760-v1.mid
#   inflating: POP909-761.mid
#   inflating: POP909-761-v1.mid
#   inflating: POP909-762.mid
#   inflating: POP909-762-v1.mid
#   inflating: POP909-762-v2.mid
#   inflating: POP909-763.mid
#   inflating: POP909-763-v1.mid
#   inflating: POP909-763-v2.mid
#   inflating: POP909-764.mid
#   inflating: POP909-764-v1.mid
#   inflating: POP909-765.mid
#   inflating: POP909-765-v1.mid
#   inflating: POP909-765-v2.mid
#   inflating: POP909-765-v3.mid
#   inflating: POP909-767.mid
#   inflating: POP909-767-v1.mid
#   inflating: POP909-768.mid
#   inflating: POP909-768-v1.mid
#   inflating: POP909-769.mid
#   inflating: POP909-769-v1.mid
#   inflating: POP909-769-v2.mid
#   inflating: POP909-770.mid
#   inflating: POP909-770-v1.mid
#   inflating: POP909-771.mid
#   inflating: POP909-771-v1.mid
#   inflating: POP909-772.mid
#   inflating: POP909-772-v1.mid
#   inflating: POP909-773-v1.mid
#   inflating: POP909-774.mid
#   inflating: POP909-774-v1.mid
#   inflating: POP909-775.mid
#   inflating: POP909-775-v1.mid
#   inflating: POP909-775-v2.mid
#   inflating: POP909-775-v3.mid
#   inflating: POP909-775-v4.mid
#   inflating: POP909-775-v5.mid
#   inflating: POP909-775-v6.mid
#   inflating: POP909-775-v7.mid
#   inflating: POP909-775-v8.mid
#   inflating: POP909-775-v9.mid
#   inflating: POP909-776.mid
#   inflating: POP909-776-v1.mid
#   inflating: POP909-776-v2.mid
#   inflating: POP909-777.mid
#   inflating: POP909-777-v1.mid
#   inflating: POP909-778.mid
#   inflating: POP909-778-v1.mid
#   inflating: POP909-778-v2.mid
#   inflating: POP909-779.mid
#   inflating: POP909-779-v1.mid
#   inflating: POP909-780.mid
#   inflating: POP909-780-v1.mid
#   inflating: POP909-780-v2.mid
#   inflating: POP909-781.mid
#   inflating: POP909-781-v1.mid
#   inflating: POP909-781-v2.mid
#   inflating: POP909-781-v3.mid
#   inflating: POP909-781-v7.mid
#   inflating: POP909-782.mid
#   inflating: POP909-782-v1.mid
#   inflating: POP909-783.mid
#   inflating: POP909-783-v1.mid
#   inflating: POP909-784.mid
#   inflating: POP909-784-v1.mid
#   inflating: POP909-785.mid
#   inflating: POP909-785-v1.mid
#   inflating: POP909-789.mid
#   inflating: POP909-789-v1.mid
#   inflating: POP909-789-v2.mid
#   inflating: POP909-789-v3.mid
#   inflating: POP909-789-v4.mid
#   inflating: POP909-789-v5.mid
#   inflating: POP909-789-v6.mid
#   inflating: POP909-790-v1.mid
#   inflating: POP909-790-v2.mid
#   inflating: POP909-790-v3.mid
#   inflating: POP909-792.mid
#   inflating: POP909-792-v1.mid
#   inflating: POP909-792-v2.mid
#   inflating: POP909-792-v3.mid
#   inflating: POP909-792-v4.mid
#   inflating: POP909-793.mid
#   inflating: POP909-793-v1.mid
#   inflating: POP909-793-v2.mid
#   inflating: POP909-794.mid
#   inflating: POP909-794-v1.mid
#   inflating: POP909-794-v2.mid
#   inflating: POP909-795.mid
#   inflating: POP909-795-v1.mid
#   inflating: POP909-795-v2.mid
#   inflating: POP909-795-v3.mid
#   inflating: POP909-795-v4.mid
#   inflating: POP909-795-v5.mid
#   inflating: POP909-795-v6.mid
#   inflating: POP909-796.mid
#   inflating: POP909-796-v1.mid
#   inflating: POP909-796-v2.mid
#   inflating: POP909-796-v3.mid
#   inflating: POP909-796-v4.mid
#   inflating: POP909-796-v5.mid
#   inflating: POP909-798.mid
#   inflating: POP909-798-v1.mid
#   inflating: POP909-798-v2.mid
#   inflating: POP909-798-v3.mid
#   inflating: POP909-798-v4.mid
#   inflating: POP909-799.mid
#   inflating: POP909-799-v1.mid
#   inflating: POP909-799-v2.mid
#   inflating: POP909-799-v3.mid
#   inflating: POP909-799-v4.mid
#   inflating: POP909-799-v5.mid
#   inflating: POP909-799-v6.mid
#   inflating: POP909-800.mid
#   inflating: POP909-800-v1.mid
#   inflating: POP909-801.mid
#   inflating: POP909-801-v1.mid
#   inflating: POP909-802.mid
#   inflating: POP909-802-v1.mid
#   inflating: POP909-803.mid
#   inflating: POP909-803-v1.mid
#   inflating: POP909-804.mid
#   inflating: POP909-804-v1.mid
#   inflating: POP909-804-v2.mid
#   inflating: POP909-804-v3.mid
#   inflating: POP909-804-v4.mid
#   inflating: POP909-804-v5.mid
#   inflating: POP909-805.mid
#   inflating: POP909-805-v1.mid
#   inflating: POP909-806.mid
#   inflating: POP909-806-v6.mid
#   inflating: POP909-807-v1.mid
#   inflating: POP909-808.mid
#   inflating: POP909-808-v1.mid
#   inflating: POP909-809.mid
#   inflating: POP909-809-v1.mid
#   inflating: POP909-810.mid
#   inflating: POP909-810-v1.mid
#   inflating: POP909-810-v2.mid
#   inflating: POP909-810-v3.mid
#   inflating: POP909-811.mid
#   inflating: POP909-811-v1.mid
#   inflating: POP909-811-v2.mid
#   inflating: POP909-813.mid
#   inflating: POP909-813-v1.mid
#   inflating: POP909-813-v2.mid
#   inflating: POP909-813-v3.mid
#   inflating: POP909-814.mid
#   inflating: POP909-814-v1.mid
#   inflating: POP909-815.mid
#   inflating: POP909-815-v1.mid
#   inflating: POP909-817.mid
#   inflating: POP909-817-v1.mid
#   inflating: POP909-817-v2.mid
#   inflating: POP909-817-v3.mid
#   inflating: POP909-818.mid
#   inflating: POP909-818-v1.mid
#   inflating: POP909-820.mid
#   inflating: POP909-820-v1.mid
#   inflating: POP909-820-v2.mid
#   inflating: POP909-825.mid
#   inflating: POP909-825-v1.mid
#   inflating: POP909-825-v2.mid
#   inflating: POP909-825-v3.mid
#   inflating: POP909-825-v4.mid
#   inflating: POP909-827.mid
#   inflating: POP909-827-v1.mid
#   inflating: POP909-827-v2.mid
#   inflating: POP909-827-v3.mid
#   inflating: POP909-828.mid
#   inflating: POP909-828-v1.mid
#   inflating: POP909-828-v2.mid
#   inflating: POP909-828-v3.mid
#   inflating: POP909-829.mid
#   inflating: POP909-829-v1.mid
#   inflating: POP909-829-v2.mid
#   inflating: POP909-829-v3.mid
#   inflating: POP909-830.mid
#   inflating: POP909-830-v1.mid
#   inflating: POP909-831.mid
#   inflating: POP909-831-v1.mid
#   inflating: POP909-832.mid
#   inflating: POP909-832-v1.mid
#   inflating: POP909-832-v2.mid
#   inflating: POP909-833.mid
#   inflating: POP909-833-v1.mid
#   inflating: POP909-833-v2.mid
#   inflating: POP909-834-v1.mid
#   inflating: POP909-836.mid
#   inflating: POP909-836-v1.mid
#   inflating: POP909-837.mid
#   inflating: POP909-837-v1.mid
#   inflating: POP909-837-v2.mid
#   inflating: POP909-839.mid
#   inflating: POP909-839-v1.mid
#   inflating: POP909-839-v2.mid
#   inflating: POP909-839-v3.mid
#   inflating: POP909-840.mid
#   inflating: POP909-840-v1.mid
#   inflating: POP909-840-v2.mid
#   inflating: POP909-841.mid
#   inflating: POP909-841-v1.mid
#   inflating: POP909-842.mid
#   inflating: POP909-842-v1.mid
#   inflating: POP909-843.mid
#   inflating: POP909-843-v1.mid
#   inflating: POP909-844.mid
#   inflating: POP909-844-v1.mid
#   inflating: POP909-844-v2.mid
#   inflating: POP909-845.mid
#   inflating: POP909-845-v1.mid
#   inflating: POP909-846.mid
#   inflating: POP909-846-v1.mid
#   inflating: POP909-846-v2.mid
#   inflating: POP909-847.mid
#   inflating: POP909-847-v1.mid
#   inflating: POP909-847-v2.mid
#   inflating: POP909-848.mid
#   inflating: POP909-848-v1.mid
#   inflating: POP909-848-v2.mid
#   inflating: POP909-848-v3.mid
#   inflating: POP909-849.mid
#   inflating: POP909-849-v1.mid
#   inflating: POP909-851.mid
#   inflating: POP909-851-v1.mid
#   inflating: POP909-851-v2.mid
#   inflating: POP909-852.mid
#   inflating: POP909-852-v1.mid
#   inflating: POP909-852-v2.mid
#   inflating: POP909-853.mid
#   inflating: POP909-853-v1.mid
#   inflating: POP909-855.mid
#   inflating: POP909-855-v1.mid
#   inflating: POP909-857.mid
#   inflating: POP909-857-v1.mid
#   inflating: POP909-858.mid
#   inflating: POP909-858-v1.mid
#   inflating: POP909-859.mid
#   inflating: POP909-859-v1.mid
#   inflating: POP909-859-v2.mid
#   inflating: POP909-860.mid
#   inflating: POP909-860-v1.mid
#   inflating: POP909-861.mid
#   inflating: POP909-861-v1.mid
#   inflating: POP909-862.mid
#   inflating: POP909-862-v1.mid
#   inflating: POP909-862-v2.mid
#   inflating: POP909-863.mid
#   inflating: POP909-863-v1.mid
#   inflating: POP909-863-v2.mid
#   inflating: POP909-863-v3.mid
#   inflating: POP909-864.mid
#   inflating: POP909-864-v1.mid
#   inflating: POP909-864-v2.mid
#   inflating: POP909-864-v3.mid
#   inflating: POP909-865.mid
#   inflating: POP909-865-v1.mid
#   inflating: POP909-867.mid
#   inflating: POP909-867-v1.mid
#   inflating: POP909-867-v2.mid
#   inflating: POP909-867-v3.mid
#   inflating: POP909-867-v4.mid
#   inflating: POP909-868.mid
#   inflating: POP909-868-v1.mid
#   inflating: POP909-868-v2.mid
#   inflating: POP909-869.mid
#   inflating: POP909-869-v1.mid
#   inflating: POP909-869-v2.mid
#   inflating: POP909-870.mid
#   inflating: POP909-870-v1.mid
#   inflating: POP909-870-v2.mid
#   inflating: POP909-871.mid
#   inflating: POP909-871-v1.mid
#   inflating: POP909-871-v2.mid
#   inflating: POP909-872.mid
#   inflating: POP909-872-v1.mid
#   inflating: POP909-872-v2.mid
#   inflating: POP909-873.mid
#   inflating: POP909-873-v1.mid
#   inflating: POP909-874.mid
#   inflating: POP909-874-v1.mid
#   inflating: POP909-875.mid
#   inflating: POP909-875-v1.mid
#   inflating: POP909-875-v2.mid
#   inflating: POP909-875-v3.mid
#   inflating: POP909-875-v4.mid
#   inflating: POP909-876.mid
#   inflating: POP909-876-v1.mid
#   inflating: POP909-877.mid
#   inflating: POP909-877-v1.mid
#   inflating: POP909-878.mid
#   inflating: POP909-878-v1.mid
#   inflating: POP909-878-v2.mid
#   inflating: POP909-880.mid
#   inflating: POP909-880-v1.mid
#   inflating: POP909-881.mid
#   inflating: POP909-881-v1.mid
#   inflating: POP909-882.mid
#   inflating: POP909-882-v1.mid
#   inflating: POP909-882-v2.mid
#   inflating: POP909-882-v3.mid
#   inflating: POP909-882-v4.mid
#   inflating: POP909-883.mid
#   inflating: POP909-883-v1.mid
#   inflating: POP909-887.mid
#   inflating: POP909-887-v1.mid
#   inflating: POP909-891.mid
#   inflating: POP909-891-v1.mid
#   inflating: POP909-892.mid
#   inflating: POP909-892-v1.mid
#   inflating: POP909-892-v2.mid
#   inflating: POP909-895.mid
#   inflating: POP909-895-v1.mid
#   inflating: POP909-897.mid
#   inflating: POP909-897-v1.mid
#   inflating: POP909-898.mid
#   inflating: POP909-898-v1.mid
#   inflating: POP909-898-v2.mid
#   inflating: POP909-898-v3.mid
#   inflating: POP909-898-v4.mid
#   inflating: POP909-898-v5.mid
#   inflating: POP909-899.mid
#   inflating: POP909-899-v1.mid
#   inflating: POP909-901.mid
#   inflating: POP909-901-v1.mid
#   inflating: POP909-901-v2.mid
#   inflating: POP909-901-v3.mid
#   inflating: POP909-901-v4.mid
#   inflating: POP909-902.mid
#   inflating: POP909-902-v1.mid
#   inflating: POP909-902-v2.mid
#   inflating: POP909-903.mid
#   inflating: POP909-903-v1.mid
#   inflating: POP909-903-v2.mid
#   inflating: POP909-903-v3.mid
#   inflating: POP909-903-v4.mid
#   inflating: POP909-904.mid
#   inflating: POP909-904-v1.mid
#   inflating: POP909-904-v2.mid
#   inflating: POP909-905.mid
#   inflating: POP909-905-v1.mid
#   inflating: POP909-905-v2.mid
#   inflating: POP909-905-v3.mid
#   inflating: POP909-905-v4.mid
#   inflating: POP909-905-v5.mid
#   inflating: POP909-906.mid
#   inflating: POP909-906-v1.mid
#   inflating: POP909-906-v2.mid
#   inflating: POP909-906-v3.mid
#   inflating: POP909-907.mid
#   inflating: POP909-909.mid
#   inflating: POP909-909-v1.mid
# /content

# %% [markdown]
# # (MIDI PROCESSOR)

# %%
#@title Load TMIDIX MIDI Processor

print('=' * 70)
print('Loading TMIDIX MIDI Processor...')
print('=' * 70)

def TMIDIX_MIDI_Processor(midi_file):

    melody_chords = []

    try:

        fn = os.path.basename(midi_file)

        #=======================================================
        # START PROCESSING

        raw_score = TMIDIX.midi2single_track_ms_score(midi_file)

        escore_notes = TMIDIX.advanced_score_processor(raw_score, return_enhanced_score_notes=True)[0]

        escore_notes = TMIDIX.augment_enhanced_score_notes(escore_notes, timings_divider=16)

        all_scores = []

        for ta in range(0, 6, 2):
          for pa in range(-1, 2):

            escore_notes_aug = copy.deepcopy(escore_notes)

            for e in escore_notes_aug:
              e[1] += ta
              e[2] += ta
              e[4] += pa

            violin_dscore = [d for d in escore_notes_aug if d[6] == 40]
            violin_mono_melody_score = [n[0] for n in TMIDIX.chordify_score([1000, violin_dscore])]

            piano_dscore = [d for d in escore_notes_aug if d[6] == 0]

            violin_piano_score_notes = sorted(violin_mono_melody_score+piano_dscore, key=lambda x: x[1])

            violin_piano_dscore_notes = [d[1:] for d in TMIDIX.delta_score_notes(violin_piano_score_notes,
                                                                                even_timings=True,
                                                                                compress_timings=True)]

            all_scores.append(violin_piano_dscore_notes)

        return all_scores

    except Exception as e:
      print('Error!')
      print('Exception', e)
      return None

print('Done!')
print('=' * 70)
# Out:
# ======================================================================
# Loading TMIDIX MIDI Processor...
# ======================================================================
# Done!
# ======================================================================

# %% [markdown]
# # (FILE LIST)

# %%
#@title Save file list
###########

print('=' * 70)
print('Loading MIDI files...')
print('This may take a while on a large dataset in particular.')

dataset_addr = "/content/Dataset"

# os.chdir(dataset_addr)
filez = list()
for (dirpath, dirnames, filenames) in os.walk(dataset_addr):
    filez += [os.path.join(dirpath, file) for file in filenames]
print('=' * 70)

if not filez:
    print('Could not find any MIDI files. Please check Dataset dir...')
    print('=' * 70)

else:
  print('Randomizing file list...')
  random.shuffle(filez)
  print('Done!')
  print('=' * 70)
  print('Total files:', len(filez))
  print('=' * 70)
# Out:
# ======================================================================
# Loading MIDI files...
# This may take a while on a large dataset in particular.
# ======================================================================
# Randomizing file list...
# Done!
# ======================================================================
# Total files: 2085
# ======================================================================

# %% [markdown]
# # (PROCESS MIDIs)

# %%
#@title Process MIDIs with TMIDIX MIDI processor

print('=' * 70)
print('TMIDIX MIDI Processor')
print('=' * 70)
print('Starting up...')
print('=' * 70)

###########

melody_chords_f = []

print('Processing MIDI files. Please wait...')
print('=' * 70)

for i in tqdm.tqdm(range(0, len(filez), 16)):

  with parallel_config(backend='threading', n_jobs=16, verbose = 0):

    output = Parallel()(delayed(TMIDIX_MIDI_Processor)(f) for f in filez[i:i+16])

    for o in output:

        if o is not None:
            melody_chords_f.append(o)

print('Done!')
print('=' * 70)
# Out:
# ======================================================================
# TMIDIX MIDI Processor
# ======================================================================
# Starting up...
# ======================================================================
# Processing MIDI files. Please wait...
# ======================================================================
#  65%|██████▍   | 85/131 [06:18<03:30,  4.58s/it]
# Error!
# Exception 'NoneType' object is not iterable
#  94%|█████████▍| 123/131 [09:05<00:33,  4.13s/it]
# Error!
# Exception 'NoneType' object is not iterable
# 100%|██████████| 131/131 [09:37<00:00,  4.41s/it]
# Done!
# ======================================================================

# %% [markdown]
# # (SAVE/LOAD PROCESSED MIDIs)

# %%
# @title Save processed MIDIs
TMIDIX.Tegridy_Any_Pickle_File_Writer(melody_chords_f, '/content/Processed_MIDIs')
# Out:
# Tegridy Pickle File Writer
# Creating new Dataset file...
# Dataset was saved as: /content/Processed_MIDIs.pickle
# Task complete. Enjoy! :)

# %%
# @title Load processed MIDIs
melody_chords_f = TMIDIX.Tegridy_Any_Pickle_File_Reader('/content/Processed_MIDIs')
print('Done!')
# Out:
# Tegridy Pickle File Loader
# Loading the pickle file. Please wait...
# Done!

# %% [markdown]
# # (TEST PROCESSED MIDIs)

# %%
#@title Test Processed MIDIs

train_data1 = random.choice(melody_chords_f[0])

#train_data1 = max(melody_chords_f, key = len)

print('Sample data:', train_data1[:15])

out = train_data1

patches = [0] * 16
patches[3] = 40

if len(out) != 0:

    song = out
    song_f = []

    time = 0
    dur = 0
    vel = 90
    pitch = 0
    channel = 0

    for s in song:

        time += s[0]
        dur = s[1]
        channel = s[2]
        pitch = s[3]
        vel = s[4]

        song_f.append(['note', time, dur, channel, pitch, vel ])

detailed_stats = TMIDIX.Tegridy_ms_SONG_to_MIDI_Converter(song_f,
                                                          output_signature = 'Tiny Music Transformer',
                                                          output_file_name = '/content/Tiny-Music-Transformer-Composition',
                                                          track_name='Project Los Angeles',
                                                          list_of_MIDI_patches=patches,
                                                          timings_multiplier=32
                                                          )

print('Done!')
# Out:
# Sample data: [[0, 10, 3, 85, 108, 40], [0, 22, 0, 65, 70, 0], [0, 20, 0, 61, 67, 0], [0, 32, 0, 49, 73, 0], [12, 7, 3, 73, 111, 40], [0, 19, 0, 56, 48, 0], [6, 5, 3, 75, 105, 40], [7, 10, 3, 77, 105, 40], [0, 11, 0, 65, 90, 0], [0, 12, 0, 61, 73, 0], [12, 10, 3, 82, 100, 40], [13, 44, 3, 80, 108, 40], [0, 17, 0, 60, 23, 0], [0, 17, 0, 56, 49, 0], [0, 37, 0, 41, 44, 0]]
# Converting to MIDI. Please stand-by...
# Done! Enjoy! :)
# Done!

# %% [markdown]
# # (PREP INTs)

# %%
# @title Convert processed MIDIs to INTs
SEQ_LEN = 8192
PAD_IDX = 835

print('=' * 70)

train_data = []

for m in tqdm.tqdm(melody_chords_f):
  for mm in m:

    cscore = TMIDIX.chordify_score(mm)

    dat = [834]

    first_chord = True

    for chord in cscore:

      tones_chord = sorted(set([c[3] % 12 for c in chord]))

      try:
          chord_token = TMIDIX.ALL_CHORDS_SORTED.index(tones_chord) + 512
      except:
          checked_tones_chord = TMIDIX.check_and_fix_tones_chord(tones_chord)
          chord_token = TMIDIX.ALL_CHORDS_SORTED.index(checked_tones_chord) + 512

      dat.append(chord_token)

      if first_chord:
        dat.append(0)
        first_chord = False

      for c in chord:

            if c[2] == 0:
                cha = 0
            if c[2] == 3:
                cha = 1

            if c[0] != 0:
              dat.extend([c[0], c[1]+128, ((cha * 128) + c[3])+256])
            else:
              dat.extend([c[1]+128, ((cha * 128) + c[3])+256])

    dat = dat[:SEQ_LEN+1]
    dat += [PAD_IDX] * (SEQ_LEN+1 - len(dat))

    train_data.append(dat)

# Total dict size 644

random.shuffle(train_data)

print('Done!')
print('=' * 70)
print(len(train_data), max(train_data, key=len) == min(train_data, key=len))
print('=' * 70)
print(len(max(train_data, key=len)), len(min(train_data, key=len)))
print('=' * 70)
print(train_data[0][:15])
print('=' * 70)
# Out:
# ======================================================================
# 100%|██████████| 2083/2083 [01:52<00:00, 18.53it/s]
# Done!
# ======================================================================
# 18747 True
# ======================================================================
# 8193 8193
# ======================================================================
# [834, 546, 0, 139, 320, 199, 316, 199, 313, 199, 309, 199, 301, 779, 19]
# ======================================================================

# %% [markdown]
# # (SAVE/LOAD INTs)

# %%
# @title Save INTs
TMIDIX.Tegridy_Any_Pickle_File_Writer(train_data, '/content/Training_INTs')
# Out:
# Tegridy Pickle File Writer
# Creating new Dataset file...
# Dataset was saved as: /content/Training_INTs.pickle
# Task complete. Enjoy! :)

# %%
# @title Load INTs
train_data = TMIDIX.Tegridy_Any_Pickle_File_Reader('/content/Training_INTs')
print('Done!')
# Out:
# Tegridy Pickle File Loader
# Loading the pickle file. Please wait...
# Done!

# %% [markdown]
# # (PREP MODEL)

# %%
# @title Setup and init the model

# constants

SEQ_LEN = 8192 # Models seq len
PAD_IDX = 835 # Models pad index

BATCH_SIZE = 4
NUM_EPOCHS = 200
GRADIENT_ACCUMULATE_EVERY = 4

LEARNING_RATE = 1e-4

VALIDATE_EVERY  = 100
SAVE_EVERY = 500
GENERATE_EVERY  = 100
PRINT_STATS_EVERY = 20

GENERATE_LENGTH = 32

# helpers

def cycle(loader):
    while True:
        for data in loader:
            yield data

# instantiate the model
model = TransformerWrapper(
    num_tokens = PAD_IDX+1,
    max_seq_len = SEQ_LEN,
    attn_layers = Decoder(
        dim = 512,
        depth = 8,
        heads = 8
    )
).cuda()
'''
model = TransformerWrapper(
    num_tokens = PAD_IDX+1,
    max_seq_len = SEQ_LEN,
    attn_layers = Decoder(dim = 1024,
                          depth = 8,
                          heads = 8,
                          attn_flash = True,
                          use_rmsnorm = True, # set to true to use for all layers)
                          rotary_pos_emb = True  # turns on rotary positional embedding
    ))
'''
model = AutoregressiveWrapper(model, ignore_index=PAD_IDX)


print('Done!')

summary(model)

# Dataloader

class MusicDataset(Dataset):
    def __init__(self, data, seq_len):
        super().__init__()
        self.data = data
        self.seq_len = seq_len

    def __getitem__(self, index):

        full_seq = torch.Tensor(self.data[index][:self.seq_len+1]).long()

        return full_seq.cuda()

    def __len__(self):
        return (len(self.data) // BATCH_SIZE) * BATCH_SIZE

# precision/optimizer/scaler

dtype = torch.float16

ctx = torch.amp.autocast(device_type='cuda', dtype=dtype)

optim = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)

scaler = torch.cuda.amp.GradScaler()
# Out:
# Done!
# ======================================================================
# Layer (type:depth-idx)                        Param #
# ======================================================================
# ├─TransformerWrapper: 1-1                     --
# |    └─TokenEmbedding: 2-1                    --
# |    |    └─Embedding: 3-1                    428,032
# |    └─AbsolutePositionalEmbedding: 2-2       --
# |    |    └─Embedding: 3-2                    4,194,304
# |    └─Identity: 2-3                          --
# |    └─Dropout: 2-4                           --
# |    └─Identity: 2-5                          --
# |    └─Encoder: 2-6                           --
# |    |    └─ModuleList: 3-3                   25,202,688
# |    |    └─LayerNorm: 3-4                    1,024
# |    └─Linear: 2-7                            428,868
# ======================================================================
# Total params: 30,254,916
# Trainable params: 30,254,916
# Non-trainable params: 0
# ======================================================================

# %% [markdown]
# # (TRAIN MODEL)

# %%
# @title Train the model

train_losses = []
val_losses = []

train_accs = []
val_accs = []

nsteps = 0

for ep in range(NUM_EPOCHS):

  print('=' * 70)
  print('Epoch #', ep)
  print('=' * 70)

  random.shuffle(train_data)

  train_dataset = MusicDataset(train_data, SEQ_LEN)
  val_dataset   = MusicDataset(train_data, SEQ_LEN)
  train_loader  = cycle(DataLoader(train_dataset, batch_size = BATCH_SIZE))
  val_loader    = cycle(DataLoader(val_dataset, batch_size = BATCH_SIZE))

  NUM_BATCHES = len(train_data) // BATCH_SIZE // GRADIENT_ACCUMULATE_EVERY

  for i in tqdm.tqdm(range(NUM_BATCHES), mininterval=10., desc='Training'):
      model.train()

      for __ in range(GRADIENT_ACCUMULATE_EVERY):
          with ctx:
              loss, acc = model(next(train_loader))
          loss = loss / GRADIENT_ACCUMULATE_EVERY
          scaler.scale(loss).backward(torch.ones(loss.shape).cuda())

      if i % PRINT_STATS_EVERY == 0:
          print(f'Training loss: {loss.mean().item() * GRADIENT_ACCUMULATE_EVERY}')
          print(f'Training acc: {acc.mean().item()}')

      train_losses.append(loss.mean().item() * GRADIENT_ACCUMULATE_EVERY)
      train_accs.append(acc.mean().item())

      scaler.unscale_(optim)
      torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
      scaler.step(optim)
      scaler.update()
      optim.zero_grad(set_to_none=True)

      nsteps += 1

      if i % VALIDATE_EVERY == 0:
        model.eval()
        with torch.no_grad():
          with ctx:
            val_loss, val_acc = model(next(val_loader))

            print(f'Validation loss: {val_loss.mean().item()}')
            print(f'Validation acc: {val_acc.mean().item()}')

            val_losses.append(val_loss.mean().item())
            val_accs.append(val_acc.mean().item())

            print('Plotting training loss graph...')

            tr_loss_list = train_losses
            plt.plot([i for i in range(len(tr_loss_list))] ,tr_loss_list, 'b')
            plt.show()
            plt.close()
            print('Done!')

            print('Plotting training acc graph...')

            tr_loss_list = train_accs
            plt.plot([i for i in range(len(tr_loss_list))] ,tr_loss_list, 'b')
            plt.show()
            plt.close()
            print('Done!')

            print('Plotting validation loss graph...')
            tr_loss_list = val_losses
            plt.plot([i for i in range(len(tr_loss_list))] ,tr_loss_list, 'b')
            plt.show()
            plt.close()
            print('Done!')

            print('Plotting validation acc graph...')
            tr_loss_list = val_accs
            plt.plot([i for i in range(len(tr_loss_list))] ,tr_loss_list, 'b')
            plt.show()
            plt.close()
            print('Done!')

      if i % GENERATE_EVERY == 0:
        model.eval()

        inp = random.choice(val_dataset)[:512]

        print(inp)

        with ctx:

            sample = model.generate(inp[None, ...], GENERATE_LENGTH)

        print(sample)

      if i % SAVE_EVERY == 0:

          print('Saving model progress. Please wait...')
          print('model_checkpoint_' + str(nsteps) + '_steps_' + str(round(float(train_losses[-1]), 4)) + '_loss_' + str(round(float(train_accs[-1]), 4)) + '_acc.pth')

          fname = '/content/model_checkpoint_' + str(nsteps) + '_steps_' + str(round(float(train_losses[-1]), 4)) + '_loss_' + str(round(float(train_accs[-1]), 4)) + '_acc.pth'

          torch.save(model.state_dict(), fname)

          data = [train_losses, train_accs, val_losses, val_accs]

          TMIDIX.Tegridy_Any_Pickle_File_Writer(data, '/content/losses_accs')

          print('Done!')

#======================================================================================================

print('Saving model progress. Please wait...')
print('model_checkpoint_' + str(nsteps) + '_steps_' + str(round(float(train_losses[-1]), 4)) + '_loss_' + str(round(float(train_accs[-1]), 4)) + '_acc.pth')

fname = '/content/model_checkpoint_' + str(nsteps) + '_steps_' + str(round(float(train_losses[-1]), 4)) + '_loss_' + str(round(float(train_accs[-1]), 4)) + '_acc.pth'

torch.save(model.state_dict(), fname)

print('Done!')

data = [train_losses, train_accs, val_losses, val_accs]

TMIDIX.Tegridy_Any_Pickle_File_Writer(data, '/content/losses_accuracies')

# Save training loss graph

plt.plot([i for i in range(len(train_losses))] ,train_losses, 'b')
plt.savefig('/content/training_loss_graph.png')
plt.close()
print('Done!')

# Save training acc graph

plt.plot([i for i in range(len(train_accs))] ,train_accs, 'b')
plt.savefig('/content/training_acc_graph.png')
plt.close()
print('Done!')

# Save validation loss graph

plt.plot([i for i in range(len(val_losses))] ,val_losses, 'b')
plt.savefig('/content/validation_loss_graph.png')
plt.close()
print('Done!')

# Save validation acc graph

plt.plot([i for i in range(len(val_accs))] ,val_accs, 'b')
plt.savefig('/content/validation_acc_graph.png')
plt.close()
print('Done!')
# Out:
# ======================================================================
# Epoch # 0
# ======================================================================
# Training:   0%|          | 0/1171 [00:01<?, ?it/s]
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# <ipython-input-15-c0b1f366100d> in <cell line: 11>()
#      29       for __ in range(GRADIENT_ACCUMULATE_EVERY):
#      30           with ctx:
# ---> 31               loss, acc = model(next(train_loader))
#      32           loss = loss / GRADIENT_ACCUMULATE_EVERY
#      33           scaler.scale(loss).backward(torch.ones(loss.shape).cuda())
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1509             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510         else:
# -> 1511             return self._call_impl(*args, **kwargs)
#    1512
#    1513     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1518                 or _global_backward_pre_hooks or _global_backward_hooks
#    1519                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520             return forward_call(*args, **kwargs)
#    1521
#    1522         try:
#
# /content/tegridy-tools/tegridy-tools/X-Transformer/x_transformer_1_23_2.py in forward(self, x, **kwargs)
#     677             kwargs.update(self_attn_kv_mask = mask)
#     678
# --> 679         logits, cache = self.net(
#     680             inp,
#     681             return_intermediates = True,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1509             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510         else:
# -> 1511             return self._call_impl(*args, **kwargs)
#    1512
#    1513     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1518                 or _global_backward_pre_hooks or _global_backward_hooks
#    1519                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520             return forward_call(*args, **kwargs)
#    1521
#    1522         try:
#
# /content/tegridy-tools/tegridy-tools/X-Transformer/x_transformer_1_23_2.py in forward(self, x, return_embeddings, return_logits_and_embeddings, return_intermediates, mask, return_mems, return_attn, mems, pos, prepend_embeds, sum_embeds, return_attn_z_loss, attn_z_loss_weight, seq_start_pos, cache, **kwargs)
#    2266             mems = [*mems_r, *mems_l]
#    2267
# -> 2268         x, intermediates = self.attn_layers(x, mask = mask, mems = mems, cache = cache, return_hiddens = True, seq_start_pos = seq_start_pos, **kwargs)
#    2269
#    2270         if has_memory_tokens:
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1509             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510         else:
# -> 1511             return self._call_impl(*args, **kwargs)
#    1512
#    1513     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1518                 or _global_backward_pre_hooks or _global_backward_hooks
#    1519                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520             return forward_call(*args, **kwargs)
#    1521
#    1522         try:
#
# /content/tegridy-tools/tegridy-tools/X-Transformer/x_transformer_1_23_2.py in forward(self, x, context, mask, context_mask, attn_mask, self_attn_kv_mask, mems, seq_start_pos, cache, cache_age, return_hiddens)
#    1973
#    1974             if layer_type == 'a':
# -> 1975                 out, inter = block(x, mask = mask, context_mask = self_attn_kv_mask, attn_mask = attn_mask, rel_pos = self.rel_pos, rotary_pos_emb = rotary_pos_emb, prev_attn = prev_attn, cache = next(iter_attn_cache, None), mem = layer_mem, return_intermediates = True)
#    1976             elif layer_type == 'c':
#    1977                 out, inter = block(x, context = context, mask = mask, context_mask = context_mask, prev_attn = prev_cross_attn, cache = next(iter_attn_cache, None), return_intermediates = True)
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1509             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510         else:
# -> 1511             return self._call_impl(*args, **kwargs)
#    1512
#    1513     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1518                 or _global_backward_pre_hooks or _global_backward_hooks
#    1519                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520             return forward_call(*args, **kwargs)
#    1521
#    1522         try:
#
# /content/tegridy-tools/tegridy-tools/X-Transformer/x_transformer_1_23_2.py in forward(self, x, context, mask, context_mask, attn_mask, rel_pos, rotary_pos_emb, prev_attn, mem, return_intermediates, cache)
#    1594         # attention is all we need
#    1595
# -> 1596         out, intermediates = self.attend(
#    1597             q, k, v,
#    1598             mask = final_attn_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1509             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510         else:
# -> 1511             return self._call_impl(*args, **kwargs)
#    1512
#    1513     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1518                 or _global_backward_pre_hooks or _global_backward_hooks
#    1519                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520             return forward_call(*args, **kwargs)
#    1521
#    1522         try:
#
# /content/tegridy-tools/tegridy-tools/X-Transformer/x_transformer_1_23_2.py in forward(self, q, k, v, mask, attn_bias, prev_attn)
#     351             dots = dots.masked_fill(causal_mask, mask_value)
#     352
# --> 353         pre_softmax_attn = dots.clone()
#     354
#     355         attn = self.attn_fn(dots, dim = -1)
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 4.00 GiB. GPU 0 has a total capacity of 39.56 GiB of which 2.41 GiB is free. Process 32200 has 37.14 GiB memory in use. Of the allocated memory 33.30 GiB is allocated by PyTorch, and 3.35 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)

# %% [markdown]
# # (SAVE MODEL)

# %%
# @title Manual save
print('Saving model progress. Please wait...')
print('model_checkpoint_' + str(nsteps) + '_steps_' + str(round(float(train_losses[-1]), 4)) + '_loss_' + str(round(float(train_accs[-1]), 4)) + '_acc.pth')

fname = '/content/model_checkpoint_' + str(nsteps) + '_steps_' + str(round(float(train_losses[-1]), 4)) + '_loss_' + str(round(float(train_accs[-1]), 4)) + '_acc.pth'

torch.save(model.state_dict(), fname)

print('Done!')

data = [train_losses, train_accs, val_losses, val_accs]

TMIDIX.Tegridy_Any_Pickle_File_Writer(data, '/content/losses_accuracies')

# Save training loss graph

plt.plot([i for i in range(len(train_losses))] ,train_losses, 'b')
plt.savefig('/content/training_loss_graph.png')
plt.close()
print('Done!')

# Save training acc graph

plt.plot([i for i in range(len(train_accs))] ,train_accs, 'b')
plt.savefig('/content/training_acc_graph.png')
plt.close()
print('Done!')

# Save validation loss graph

plt.plot([i for i in range(len(val_losses))] ,val_losses, 'b')
plt.savefig('/content/validation_loss_graph.png')
plt.close()
print('Done!')

# Save validation acc graph

plt.plot([i for i in range(len(val_accs))] ,val_accs, 'b')
plt.savefig('/content/validation_acc_graph.png')
plt.close()
print('Done!')

# %% [markdown]
# # (EVAL MODEL)

# %%
# @title Eval model
dtype = 'float16'
device_type = 'cuda'
ptdtype = {'float32': torch.float32, 'bfloat16': torch.bfloat16, 'float16': torch.float16}[dtype]
ctx = torch.amp.autocast(device_type=device_type, dtype=ptdtype)

model.eval()

x = torch.tensor(random.choice(train_data)[:2048], dtype=torch.long, device='cuda')[None, ...]
#x = torch.tensor([[834]] * 1, dtype=torch.long, device='cuda')


# run generation

with ctx:
    out = model.generate(x,
                        1024,
                        temperature=0.9,
                        return_prime=False,
                        verbose=True)

y = out.tolist()

print('---------------')
print(y[0])

# %%
#@title Convert output INTs to MIDI

train_data1 = y[0] # batch number goes here

print('Sample INTs', train_data1[:15])

out = train_data1

patches = [0] * 16
patches[3] = 40

if len(out) != 0:

    song = out
    song_f = []

    time = 0
    dur = 0
    vel = 90
    pitch = 0
    channel = 0

    for ss in song:

        if 0 <= ss < 128:

            time += ss

        if 128 <= ss < 256:

            dur = ss-128

        if 256 <= ss < 512:

            pitch = (ss-256) % 128

            channel = (ss-256) // 128

            if channel == 1:
              channel = 3
              vel = 110
            else:
              channel = 0
              vel = 80

            song_f.append(['note', time, dur, channel, pitch, vel ])

detailed_stats = TMIDIX.Tegridy_ms_SONG_to_MIDI_Converter(song_f,
                                                          output_signature = 'Tiny Music Transformer',
                                                          output_file_name = '/content/Tiny-Music-Transformer-Composition',
                                                          track_name='Project Los Angeles',
                                                          list_of_MIDI_patches=patches,
                                                          timings_multiplier=32
                                                          )

print('Done!')

# %% [markdown]
# # (PLOT TOKENS EMBEDDINGS)

# %%
# @title Plot model tokens embeddings
tok_emb = model.net.token_emb.emb.weight.detach().cpu().tolist()

cos_sim = metrics.pairwise_distances(
  tok_emb, metric='cosine'
)
plt.figure(figsize=(7, 7))
plt.imshow(cos_sim, cmap="inferno", interpolation="nearest")
im_ratio = cos_sim.shape[0] / cos_sim.shape[1]
plt.colorbar(fraction=0.046 * im_ratio, pad=0.04)
plt.xlabel("Position")
plt.ylabel("Position")
plt.tight_layout()
plt.plot()
plt.savefig("/content/Tiny-Music-Transformer-Tokens-Embeddings-Plot.png", bbox_inches="tight")

# %% [markdown]
# # Congrats! You did it! :)
